# %%
from langgraph.graph import StateGraph, END, add_messages
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_ollama import ChatOllama
from langchain_tavily import TavilySearch
from langchain_core.messages import BaseMessage, AIMessage
from langgraph.prebuilt import ToolNode
from typing import TypedDict, Annotated, Sequence
from dotenv import load_dotenv
import os


load_dotenv()
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash")
# model = ChatOllama(model="llama3.2")
search_tool = TavilySearch(max_results=2, search_depth = 'basic')

tools = [search_tool]
tool_model = model.bind_tools(tools=tools)

class AgentState(TypedDict):
    messages: Annotated[Sequence[BaseMessage], add_messages]

def chat_node(state: AgentState) -> AgentState:
    response = tool_model.invoke(state['messages'])
    return {"messages": [response]}

def tool_router(state: AgentState):
    last_msg = state['messages'][-1]
    if isinstance(last_msg, AIMessage) and getattr(last_msg, "tool_calls", None):
        return "tool_node"
    else:
        return END
    
tool_node = ToolNode(tools=tools)

graph = StateGraph(AgentState)

graph.add_node("chat_node", chat_node)
graph.add_node("tool_node", tool_node)

graph.set_entry_point("chat_node")
graph.add_conditional_edges("chat_node", tool_router)
graph.add_edge("tool_node", "chat_node")
app = graph.compile()

# %% [markdown]
# Stream for SSE(Server Sent Events) or one token at a time with .astream_events

# %%
from langchain_core.messages import HumanMessage
initial_state = {"messages": [HumanMessage(content="what is the weather today in Kolkata, India")]}

events = app.astream_events(input=initial_state, version="v2")

async for event in events:
    print(event)
# Out:
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='what is the weather today in Kolkata, India', additional_kwargs={}, response_metadata={})]}}, 'name': 'LangGraph', 'tags': [], 'run_id': '494a2b3c-d39d-4f81-9182-853b009c7c19', 'metadata': {}, 'parent_ids': []}
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='what is the weather today in Kolkata, India', additional_kwargs={}, response_metadata={}, id='f7c10ce6-ffaa-4452-b816-1cd8aed2bc69')]}}, 'name': 'chat_node', 'tags': ['graph:step:1'], 'run_id': '6c3c968a-6a15-4b5b-b9e0-21f5f24b947e', 'metadata': {'langgraph_step': 1, 'langgraph_node': 'chat_node', 'langgraph_triggers': ('branch:to:chat_node',), 'langgraph_path': ('__pregel_pull', 'chat_node'), 'langgraph_checkpoint_ns': 'chat_node:fe223c69-1c5d-8fe0-1d09-21a16f97715f'}, 'parent_ids': ['494a2b3c-d39d-4f81-9182-853b009c7c19']}
# {'event': 'on_chat_model_start', 'data': {'input': {'messages': [[HumanMessage(content='what is the weather today in Kolkata, India', additional_kwargs={}, response_metadata={}, id='f7c10ce6-ffaa-4452-b816-1cd8aed2bc69')]]}}, 'name': 'ChatGoogleGenerativeAI', 'tags': ['seq:step:1'], 'run_id': 'e78d95e3-b434-45d6-95aa-b67d099f029b', 'metadata': {'langgraph_step': 1, 'langgraph_node': 'chat_node', 'langgraph_triggers': ('branch:to:chat_node',), 'langgraph_path': ('__pregel_pull', 'chat_node'), 'langgraph_checkpoint_ns': 'chat_node:fe223c69-1c5d-8fe0-1d09-21a16f97715f', 'checkpoint_ns': 'chat_node:fe223c69-1c5d-8fe0-1d09-21a16f97715f', 'ls_provider': 'google_genai', 'ls_model_name': 'gemini-2.5-flash', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['494a2b3c-d39d-4f81-9182-853b009c7c19', '6c3c968a-6a15-4b5b-b9e0-21f5f24b947e']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={'function_call': {'name': 'tavily_search', 'arguments': '{"query": "weather today in Kolkata, India"}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'grounding_metadata': {}, 'model_provider': 'google_genai'}, id='lc_run--e78d95e3-b434-45d6-95aa-b67d099f029b', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'weather today in Kolkata, India'}, 'id': 'eb2f9dd7-3ef8-4ab8-93e7-9f017242d2cb', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1546, 'output_tokens': 87, 'total_tokens': 1633, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 65}}, tool_call_chunks=[{'name': 'tavily_search', 'args': '{"query": "weather today in Kolkata, India"}', 'id': 'eb2f9dd7-3ef8-4ab8-93e7-9f017242d2cb', 'index': None, 'type': 'tool_call_chunk'}])}, 'run_id': 'e78d95e3-b434-45d6-95aa-b67d099f029b', 'name': 'ChatGoogleGenerativeAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'chat_node', 'langgraph_triggers': ('branch:to:chat_node',), 'langgraph_path': ('__pregel_pull', 'chat_node'), 'langgraph_checkpoint_ns': 'chat_node:fe223c69-1c5d-8fe0-1d09-21a16f97715f', 'checkpoint_ns': 'chat_node:fe223c69-1c5d-8fe0-1d09-21a16f97715f', 'ls_provider': 'google_genai', 'ls_model_name': 'gemini-2.5-flash', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['494a2b3c-d39d-4f81-9182-853b009c7c19', '6c3c968a-6a15-4b5b-b9e0-21f5f24b947e']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--e78d95e3-b434-45d6-95aa-b67d099f029b', chunk_position='last')}, 'run_id': 'e78d95e3-b434-45d6-95aa-b67d099f029b', 'name': 'ChatGoogleGenerativeAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'chat_node', 'langgraph_triggers': ('branch:to:chat_node',), 'langgraph_path': ('__pregel_pull', 'chat_node'), 'langgraph_checkpoint_ns': 'chat_node:fe223c69-1c5d-8fe0-1d09-21a16f97715f', 'checkpoint_ns': 'chat_node:fe223c69-1c5d-8fe0-1d09-21a16f97715f', 'ls_provider': 'google_genai', 'ls_model_name': 'gemini-2.5-flash', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['494a2b3c-d39d-4f81-9182-853b009c7c19', '6c3c968a-6a15-4b5b-b9e0-21f5f24b947e']}
# {'event': 'on_chat_model_end', 'data': {'output': AIMessage(content='', additional_kwargs={'function_call': {'name': 'tavily_search', 'arguments': '{"query": "weather today in Kolkata, India"}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'grounding_metadata': {}, 'model_provider': 'google_genai'}, id='lc_run--e78d95e3-b434-45d6-95aa-b67d099f029b', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'weather today in Kolkata, India'}, 'id': 'eb2f9dd7-3ef8-4ab8-93e7-9f017242d2cb', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1546, 'output_tokens': 87, 'total_tokens': 1633, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 65}}), 'input': {'messages': [[HumanMessage(content='what is the weather today in Kolkata, India', additional_kwargs={}, response_metadata={}, id='f7c10ce6-ffaa-4452-b816-1cd8aed2bc69')]]}}, 'run_id': 'e78d95e3-b434-45d6-95aa-b67d099f029b', 'name': 'ChatGoogleGenerativeAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'chat_node', 'langgraph_triggers': ('branch:to:chat_node',), 'langgraph_path': ('__pregel_pull', 'chat_node'), 'langgraph_checkpoint_ns': 'chat_node:fe223c69-1c5d-8fe0-1d09-21a16f97715f', 'checkpoint_ns': 'chat_node:fe223c69-1c5d-8fe0-1d09-21a16f97715f', 'ls_provider': 'google_genai', 'ls_model_name': 'gemini-2.5-flash', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['494a2b3c-d39d-4f81-9182-853b009c7c19', '6c3c968a-6a15-4b5b-b9e0-21f5f24b947e']}
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='what is the weather today in Kolkata, India', additional_kwargs={}, response_metadata={}, id='f7c10ce6-ffaa-4452-b816-1cd8aed2bc69'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'tavily_search', 'arguments': '{"query": "weather today in Kolkata, India"}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'grounding_metadata': {}, 'model_provider': 'google_genai'}, id='lc_run--e78d95e3-b434-45d6-95aa-b67d099f029b', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'weather today in Kolkata, India'}, 'id': 'eb2f9dd7-3ef8-4ab8-93e7-9f017242d2cb', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1546, 'output_tokens': 87, 'total_tokens': 1633, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 65}})]}}, 'name': 'tool_router', 'tags': ['seq:step:3'], 'run_id': 'c014b6e9-91f3-432a-a523-08fba47604e9', 'metadata': {'langgraph_step': 1, 'langgraph_node': 'chat_node', 'langgraph_triggers': ('branch:to:chat_node',), 'langgraph_path': ('__pregel_pull', 'chat_node'), 'langgraph_checkpoint_ns': 'chat_node:fe223c69-1c5d-8fe0-1d09-21a16f97715f'}, 'parent_ids': ['494a2b3c-d39d-4f81-9182-853b009c7c19', '6c3c968a-6a15-4b5b-b9e0-21f5f24b947e']}
# {'event': 'on_chain_end', 'data': {'output': 'tool_node', 'input': {'messages': [HumanMessage(content='what is the weather today in Kolkata, India', additional_kwargs={}, response_metadata={}, id='f7c10ce6-ffaa-4452-b816-1cd8aed2bc69'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'tavily_search', 'arguments': '{"query": "weather today in Kolkata, India"}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'grounding_metadata': {}, 'model_provider': 'google_genai'}, id='lc_run--e78d95e3-b434-45d6-95aa-b67d099f029b', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'weather today in Kolkata, India'}, 'id': 'eb2f9dd7-3ef8-4ab8-93e7-9f017242d2cb', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1546, 'output_tokens': 87, 'total_tokens': 1633, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 65}})]}}, 'run_id': 'c014b6e9-91f3-432a-a523-08fba47604e9', 'name': 'tool_router', 'tags': ['seq:step:3'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'chat_node', 'langgraph_triggers': ('branch:to:chat_node',), 'langgraph_path': ('__pregel_pull', 'chat_node'), 'langgraph_checkpoint_ns': 'chat_node:fe223c69-1c5d-8fe0-1d09-21a16f97715f'}, 'parent_ids': ['494a2b3c-d39d-4f81-9182-853b009c7c19', '6c3c968a-6a15-4b5b-b9e0-21f5f24b947e']}
# {'event': 'on_chain_stream', 'run_id': '6c3c968a-6a15-4b5b-b9e0-21f5f24b947e', 'name': 'chat_node', 'tags': ['graph:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'chat_node', 'langgraph_triggers': ('branch:to:chat_node',), 'langgraph_path': ('__pregel_pull', 'chat_node'), 'langgraph_checkpoint_ns': 'chat_node:fe223c69-1c5d-8fe0-1d09-21a16f97715f'}, 'data': {'chunk': {'messages': [AIMessage(content='', additional_kwargs={'function_call': {'name': 'tavily_search', 'arguments': '{"query": "weather today in Kolkata, India"}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'grounding_metadata': {}, 'model_provider': 'google_genai'}, id='lc_run--e78d95e3-b434-45d6-95aa-b67d099f029b', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'weather today in Kolkata, India'}, 'id': 'eb2f9dd7-3ef8-4ab8-93e7-9f017242d2cb', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1546, 'output_tokens': 87, 'total_tokens': 1633, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 65}})]}}, 'parent_ids': ['494a2b3c-d39d-4f81-9182-853b009c7c19']}
# {'event': 'on_chain_end', 'data': {'output': {'messages': [AIMessage(content='', additional_kwargs={'function_call': {'name': 'tavily_search', 'arguments': '{"query": "weather today in Kolkata, India"}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'grounding_metadata': {}, 'model_provider': 'google_genai'}, id='lc_run--e78d95e3-b434-45d6-95aa-b67d099f029b', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'weather today in Kolkata, India'}, 'id': 'eb2f9dd7-3ef8-4ab8-93e7-9f017242d2cb', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1546, 'output_tokens': 87, 'total_tokens': 1633, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 65}})]}, 'input': {'messages': [HumanMessage(content='what is the weather today in Kolkata, India', additional_kwargs={}, response_metadata={}, id='f7c10ce6-ffaa-4452-b816-1cd8aed2bc69')]}}, 'run_id': '6c3c968a-6a15-4b5b-b9e0-21f5f24b947e', 'name': 'chat_node', 'tags': ['graph:step:1'], 'metadata': {'langgraph_step': 1, 'langgraph_node': 'chat_node', 'langgraph_triggers': ('branch:to:chat_node',), 'langgraph_path': ('__pregel_pull', 'chat_node'), 'langgraph_checkpoint_ns': 'chat_node:fe223c69-1c5d-8fe0-1d09-21a16f97715f'}, 'parent_ids': ['494a2b3c-d39d-4f81-9182-853b009c7c19']}
# {'event': 'on_chain_stream', 'run_id': '494a2b3c-d39d-4f81-9182-853b009c7c19', 'name': 'LangGraph', 'tags': [], 'metadata': {}, 'data': {'chunk': {'chat_node': {'messages': [AIMessage(content='', additional_kwargs={'function_call': {'name': 'tavily_search', 'arguments': '{"query": "weather today in Kolkata, India"}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'grounding_metadata': {}, 'model_provider': 'google_genai'}, id='lc_run--e78d95e3-b434-45d6-95aa-b67d099f029b', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'weather today in Kolkata, India'}, 'id': 'eb2f9dd7-3ef8-4ab8-93e7-9f017242d2cb', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1546, 'output_tokens': 87, 'total_tokens': 1633, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 65}})]}}}, 'parent_ids': []}
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='what is the weather today in Kolkata, India', additional_kwargs={}, response_metadata={}, id='f7c10ce6-ffaa-4452-b816-1cd8aed2bc69'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'tavily_search', 'arguments': '{"query": "weather today in Kolkata, India"}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'grounding_metadata': {}, 'model_provider': 'google_genai'}, id='lc_run--e78d95e3-b434-45d6-95aa-b67d099f029b', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'weather today in Kolkata, India'}, 'id': 'eb2f9dd7-3ef8-4ab8-93e7-9f017242d2cb', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1546, 'output_tokens': 87, 'total_tokens': 1633, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 65}})]}}, 'name': 'tool_node', 'tags': ['graph:step:2'], 'run_id': '4b37cf8e-beb6-4917-873c-644b77f37b8c', 'metadata': {'langgraph_step': 2, 'langgraph_node': 'tool_node', 'langgraph_triggers': ('branch:to:tool_node',), 'langgraph_path': ('__pregel_pull', 'tool_node'), 'langgraph_checkpoint_ns': 'tool_node:a72013c3-9091-a9c1-9368-d336988939f0'}, 'parent_ids': ['494a2b3c-d39d-4f81-9182-853b009c7c19']}
# {'event': 'on_tool_start', 'data': {'input': {'query': 'weather today in Kolkata, India'}}, 'name': 'tavily_search', 'tags': ['seq:step:1'], 'run_id': 'ca14b641-ebff-459c-92ed-47e8d1653bda', 'metadata': {'langgraph_step': 2, 'langgraph_node': 'tool_node', 'langgraph_triggers': ('branch:to:tool_node',), 'langgraph_path': ('__pregel_pull', 'tool_node'), 'langgraph_checkpoint_ns': 'tool_node:a72013c3-9091-a9c1-9368-d336988939f0', 'checkpoint_ns': 'tool_node:a72013c3-9091-a9c1-9368-d336988939f0'}, 'parent_ids': ['494a2b3c-d39d-4f81-9182-853b009c7c19', '4b37cf8e-beb6-4917-873c-644b77f37b8c']}
# {'event': 'on_tool_end', 'data': {'output': ToolMessage(content='{"query": "weather today in Kolkata, India", "follow_up_questions": null, "answer": null, "images": [], "results": [{"title": "Weather in Kolkata, India", "url": "https://www.weatherapi.com/", "content": "{\'location\': {\'name\': \'Kolkata\', \'region\': \'West Bengal\', \'country\': \'India\', \'lat\': 22.5697, \'lon\': 88.3697, \'tz_id\': \'Asia/Kolkata\', \'localtime_epoch\': 1762588137, \'localtime\': \'2025-11-08 13:18\'}, \'current\': {\'last_updated_epoch\': 1762587900, \'last_updated\': \'2025-11-08 13:15\', \'temp_c\': 30.0, \'temp_f\': 86.0, \'is_day\': 1, \'condition\': {\'text\': \'Mist\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/143.png\', \'code\': 1030}, \'wind_mph\': 10.1, \'wind_kph\': 16.2, \'wind_degree\': 341, \'wind_dir\': \'NNW\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.85, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 35, \'cloud\': 0, \'feelslike_c\': 29.4, \'feelslike_f\': 85.0, \'windchill_c\': 30.1, \'windchill_f\': 86.1, \'heatindex_c\': 29.5, \'heatindex_f\': 85.2, \'dewpoint_c\': 12.7, \'dewpoint_f\': 54.9, \'vis_km\': 4.5, \'vis_miles\': 2.0, \'uv\': 4.6, \'gust_mph\': 11.6, \'gust_kph\': 18.6}}", "score": 0.9876881, "raw_content": null}, {"url": "https://www.qweather.com/en/weather30d/kolkata-65929.html", "title": "Kolkata 30 days weather forecast, Kolkata weather forecast", "content": "Kolkata. West Bengal - India. 2025-11-08. In the next 30 days, there will be 3 days of rain, the Max Temp is 32°(14-Nov, 15-Nov, 16-Nov) and the Min Temp is", "score": 0.9014448, "raw_content": null}], "response_time": 1.51, "request_id": "fe456668-a1b3-4b09-8256-ddf08bd97d94"}', name='tavily_search', tool_call_id='eb2f9dd7-3ef8-4ab8-93e7-9f017242d2cb'), 'input': {'query': 'weather today in Kolkata, India'}}, 'run_id': 'ca14b641-ebff-459c-92ed-47e8d1653bda', 'name': 'tavily_search', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 2, 'langgraph_node': 'tool_node', 'langgraph_triggers': ('branch:to:tool_node',), 'langgraph_path': ('__pregel_pull', 'tool_node'), 'langgraph_checkpoint_ns': 'tool_node:a72013c3-9091-a9c1-9368-d336988939f0', 'checkpoint_ns': 'tool_node:a72013c3-9091-a9c1-9368-d336988939f0'}, 'parent_ids': ['494a2b3c-d39d-4f81-9182-853b009c7c19', '4b37cf8e-beb6-4917-873c-644b77f37b8c']}
# {'event': 'on_chain_stream', 'run_id': '4b37cf8e-beb6-4917-873c-644b77f37b8c', 'name': 'tool_node', 'tags': ['graph:step:2'], 'metadata': {'langgraph_step': 2, 'langgraph_node': 'tool_node', 'langgraph_triggers': ('branch:to:tool_node',), 'langgraph_path': ('__pregel_pull', 'tool_node'), 'langgraph_checkpoint_ns': 'tool_node:a72013c3-9091-a9c1-9368-d336988939f0'}, 'data': {'chunk': {'messages': [ToolMessage(content='{"query": "weather today in Kolkata, India", "follow_up_questions": null, "answer": null, "images": [], "results": [{"title": "Weather in Kolkata, India", "url": "https://www.weatherapi.com/", "content": "{\'location\': {\'name\': \'Kolkata\', \'region\': \'West Bengal\', \'country\': \'India\', \'lat\': 22.5697, \'lon\': 88.3697, \'tz_id\': \'Asia/Kolkata\', \'localtime_epoch\': 1762588137, \'localtime\': \'2025-11-08 13:18\'}, \'current\': {\'last_updated_epoch\': 1762587900, \'last_updated\': \'2025-11-08 13:15\', \'temp_c\': 30.0, \'temp_f\': 86.0, \'is_day\': 1, \'condition\': {\'text\': \'Mist\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/143.png\', \'code\': 1030}, \'wind_mph\': 10.1, \'wind_kph\': 16.2, \'wind_degree\': 341, \'wind_dir\': \'NNW\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.85, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 35, \'cloud\': 0, \'feelslike_c\': 29.4, \'feelslike_f\': 85.0, \'windchill_c\': 30.1, \'windchill_f\': 86.1, \'heatindex_c\': 29.5, \'heatindex_f\': 85.2, \'dewpoint_c\': 12.7, \'dewpoint_f\': 54.9, \'vis_km\': 4.5, \'vis_miles\': 2.0, \'uv\': 4.6, \'gust_mph\': 11.6, \'gust_kph\': 18.6}}", "score": 0.9876881, "raw_content": null}, {"url": "https://www.qweather.com/en/weather30d/kolkata-65929.html", "title": "Kolkata 30 days weather forecast, Kolkata weather forecast", "content": "Kolkata. West Bengal - India. 2025-11-08. In the next 30 days, there will be 3 days of rain, the Max Temp is 32°(14-Nov, 15-Nov, 16-Nov) and the Min Temp is", "score": 0.9014448, "raw_content": null}], "response_time": 1.51, "request_id": "fe456668-a1b3-4b09-8256-ddf08bd97d94"}', name='tavily_search', tool_call_id='eb2f9dd7-3ef8-4ab8-93e7-9f017242d2cb')]}}, 'parent_ids': ['494a2b3c-d39d-4f81-9182-853b009c7c19']}
# {'event': 'on_chain_end', 'data': {'output': {'messages': [ToolMessage(content='{"query": "weather today in Kolkata, India", "follow_up_questions": null, "answer": null, "images": [], "results": [{"title": "Weather in Kolkata, India", "url": "https://www.weatherapi.com/", "content": "{\'location\': {\'name\': \'Kolkata\', \'region\': \'West Bengal\', \'country\': \'India\', \'lat\': 22.5697, \'lon\': 88.3697, \'tz_id\': \'Asia/Kolkata\', \'localtime_epoch\': 1762588137, \'localtime\': \'2025-11-08 13:18\'}, \'current\': {\'last_updated_epoch\': 1762587900, \'last_updated\': \'2025-11-08 13:15\', \'temp_c\': 30.0, \'temp_f\': 86.0, \'is_day\': 1, \'condition\': {\'text\': \'Mist\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/143.png\', \'code\': 1030}, \'wind_mph\': 10.1, \'wind_kph\': 16.2, \'wind_degree\': 341, \'wind_dir\': \'NNW\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.85, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 35, \'cloud\': 0, \'feelslike_c\': 29.4, \'feelslike_f\': 85.0, \'windchill_c\': 30.1, \'windchill_f\': 86.1, \'heatindex_c\': 29.5, \'heatindex_f\': 85.2, \'dewpoint_c\': 12.7, \'dewpoint_f\': 54.9, \'vis_km\': 4.5, \'vis_miles\': 2.0, \'uv\': 4.6, \'gust_mph\': 11.6, \'gust_kph\': 18.6}}", "score": 0.9876881, "raw_content": null}, {"url": "https://www.qweather.com/en/weather30d/kolkata-65929.html", "title": "Kolkata 30 days weather forecast, Kolkata weather forecast", "content": "Kolkata. West Bengal - India. 2025-11-08. In the next 30 days, there will be 3 days of rain, the Max Temp is 32°(14-Nov, 15-Nov, 16-Nov) and the Min Temp is", "score": 0.9014448, "raw_content": null}], "response_time": 1.51, "request_id": "fe456668-a1b3-4b09-8256-ddf08bd97d94"}', name='tavily_search', tool_call_id='eb2f9dd7-3ef8-4ab8-93e7-9f017242d2cb')]}, 'input': {'messages': [HumanMessage(content='what is the weather today in Kolkata, India', additional_kwargs={}, response_metadata={}, id='f7c10ce6-ffaa-4452-b816-1cd8aed2bc69'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'tavily_search', 'arguments': '{"query": "weather today in Kolkata, India"}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'grounding_metadata': {}, 'model_provider': 'google_genai'}, id='lc_run--e78d95e3-b434-45d6-95aa-b67d099f029b', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'weather today in Kolkata, India'}, 'id': 'eb2f9dd7-3ef8-4ab8-93e7-9f017242d2cb', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1546, 'output_tokens': 87, 'total_tokens': 1633, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 65}})]}}, 'run_id': '4b37cf8e-beb6-4917-873c-644b77f37b8c', 'name': 'tool_node', 'tags': ['graph:step:2'], 'metadata': {'langgraph_step': 2, 'langgraph_node': 'tool_node', 'langgraph_triggers': ('branch:to:tool_node',), 'langgraph_path': ('__pregel_pull', 'tool_node'), 'langgraph_checkpoint_ns': 'tool_node:a72013c3-9091-a9c1-9368-d336988939f0'}, 'parent_ids': ['494a2b3c-d39d-4f81-9182-853b009c7c19']}
# {'event': 'on_chain_stream', 'run_id': '494a2b3c-d39d-4f81-9182-853b009c7c19', 'name': 'LangGraph', 'tags': [], 'metadata': {}, 'data': {'chunk': {'tool_node': {'messages': [ToolMessage(content='{"query": "weather today in Kolkata, India", "follow_up_questions": null, "answer": null, "images": [], "results": [{"title": "Weather in Kolkata, India", "url": "https://www.weatherapi.com/", "content": "{\'location\': {\'name\': \'Kolkata\', \'region\': \'West Bengal\', \'country\': \'India\', \'lat\': 22.5697, \'lon\': 88.3697, \'tz_id\': \'Asia/Kolkata\', \'localtime_epoch\': 1762588137, \'localtime\': \'2025-11-08 13:18\'}, \'current\': {\'last_updated_epoch\': 1762587900, \'last_updated\': \'2025-11-08 13:15\', \'temp_c\': 30.0, \'temp_f\': 86.0, \'is_day\': 1, \'condition\': {\'text\': \'Mist\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/143.png\', \'code\': 1030}, \'wind_mph\': 10.1, \'wind_kph\': 16.2, \'wind_degree\': 341, \'wind_dir\': \'NNW\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.85, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 35, \'cloud\': 0, \'feelslike_c\': 29.4, \'feelslike_f\': 85.0, \'windchill_c\': 30.1, \'windchill_f\': 86.1, \'heatindex_c\': 29.5, \'heatindex_f\': 85.2, \'dewpoint_c\': 12.7, \'dewpoint_f\': 54.9, \'vis_km\': 4.5, \'vis_miles\': 2.0, \'uv\': 4.6, \'gust_mph\': 11.6, \'gust_kph\': 18.6}}", "score": 0.9876881, "raw_content": null}, {"url": "https://www.qweather.com/en/weather30d/kolkata-65929.html", "title": "Kolkata 30 days weather forecast, Kolkata weather forecast", "content": "Kolkata. West Bengal - India. 2025-11-08. In the next 30 days, there will be 3 days of rain, the Max Temp is 32°(14-Nov, 15-Nov, 16-Nov) and the Min Temp is", "score": 0.9014448, "raw_content": null}], "response_time": 1.51, "request_id": "fe456668-a1b3-4b09-8256-ddf08bd97d94"}', name='tavily_search', id='68ece54e-13f4-4f37-bfbf-f73c21b38188', tool_call_id='eb2f9dd7-3ef8-4ab8-93e7-9f017242d2cb')]}}}, 'parent_ids': []}
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='what is the weather today in Kolkata, India', additional_kwargs={}, response_metadata={}, id='f7c10ce6-ffaa-4452-b816-1cd8aed2bc69'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'tavily_search', 'arguments': '{"query": "weather today in Kolkata, India"}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'grounding_metadata': {}, 'model_provider': 'google_genai'}, id='lc_run--e78d95e3-b434-45d6-95aa-b67d099f029b', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'weather today in Kolkata, India'}, 'id': 'eb2f9dd7-3ef8-4ab8-93e7-9f017242d2cb', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1546, 'output_tokens': 87, 'total_tokens': 1633, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 65}}), ToolMessage(content='{"query": "weather today in Kolkata, India", "follow_up_questions": null, "answer": null, "images": [], "results": [{"title": "Weather in Kolkata, India", "url": "https://www.weatherapi.com/", "content": "{\'location\': {\'name\': \'Kolkata\', \'region\': \'West Bengal\', \'country\': \'India\', \'lat\': 22.5697, \'lon\': 88.3697, \'tz_id\': \'Asia/Kolkata\', \'localtime_epoch\': 1762588137, \'localtime\': \'2025-11-08 13:18\'}, \'current\': {\'last_updated_epoch\': 1762587900, \'last_updated\': \'2025-11-08 13:15\', \'temp_c\': 30.0, \'temp_f\': 86.0, \'is_day\': 1, \'condition\': {\'text\': \'Mist\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/143.png\', \'code\': 1030}, \'wind_mph\': 10.1, \'wind_kph\': 16.2, \'wind_degree\': 341, \'wind_dir\': \'NNW\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.85, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 35, \'cloud\': 0, \'feelslike_c\': 29.4, \'feelslike_f\': 85.0, \'windchill_c\': 30.1, \'windchill_f\': 86.1, \'heatindex_c\': 29.5, \'heatindex_f\': 85.2, \'dewpoint_c\': 12.7, \'dewpoint_f\': 54.9, \'vis_km\': 4.5, \'vis_miles\': 2.0, \'uv\': 4.6, \'gust_mph\': 11.6, \'gust_kph\': 18.6}}", "score": 0.9876881, "raw_content": null}, {"url": "https://www.qweather.com/en/weather30d/kolkata-65929.html", "title": "Kolkata 30 days weather forecast, Kolkata weather forecast", "content": "Kolkata. West Bengal - India. 2025-11-08. In the next 30 days, there will be 3 days of rain, the Max Temp is 32°(14-Nov, 15-Nov, 16-Nov) and the Min Temp is", "score": 0.9014448, "raw_content": null}], "response_time": 1.51, "request_id": "fe456668-a1b3-4b09-8256-ddf08bd97d94"}', name='tavily_search', id='68ece54e-13f4-4f37-bfbf-f73c21b38188', tool_call_id='eb2f9dd7-3ef8-4ab8-93e7-9f017242d2cb')]}}, 'name': 'chat_node', 'tags': ['graph:step:3'], 'run_id': 'c20f58c8-a3f5-4d59-a3a3-d16a7eebc5bd', 'metadata': {'langgraph_step': 3, 'langgraph_node': 'chat_node', 'langgraph_triggers': ('branch:to:chat_node',), 'langgraph_path': ('__pregel_pull', 'chat_node'), 'langgraph_checkpoint_ns': 'chat_node:e68bbd3f-b653-0b2d-1dcf-6d781041d8f9'}, 'parent_ids': ['494a2b3c-d39d-4f81-9182-853b009c7c19']}
# {'event': 'on_chat_model_start', 'data': {'input': {'messages': [[HumanMessage(content='what is the weather today in Kolkata, India', additional_kwargs={}, response_metadata={}, id='f7c10ce6-ffaa-4452-b816-1cd8aed2bc69'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'tavily_search', 'arguments': '{"query": "weather today in Kolkata, India"}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'grounding_metadata': {}, 'model_provider': 'google_genai'}, id='lc_run--e78d95e3-b434-45d6-95aa-b67d099f029b', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'weather today in Kolkata, India'}, 'id': 'eb2f9dd7-3ef8-4ab8-93e7-9f017242d2cb', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1546, 'output_tokens': 87, 'total_tokens': 1633, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 65}}), ToolMessage(content='{"query": "weather today in Kolkata, India", "follow_up_questions": null, "answer": null, "images": [], "results": [{"title": "Weather in Kolkata, India", "url": "https://www.weatherapi.com/", "content": "{\'location\': {\'name\': \'Kolkata\', \'region\': \'West Bengal\', \'country\': \'India\', \'lat\': 22.5697, \'lon\': 88.3697, \'tz_id\': \'Asia/Kolkata\', \'localtime_epoch\': 1762588137, \'localtime\': \'2025-11-08 13:18\'}, \'current\': {\'last_updated_epoch\': 1762587900, \'last_updated\': \'2025-11-08 13:15\', \'temp_c\': 30.0, \'temp_f\': 86.0, \'is_day\': 1, \'condition\': {\'text\': \'Mist\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/143.png\', \'code\': 1030}, \'wind_mph\': 10.1, \'wind_kph\': 16.2, \'wind_degree\': 341, \'wind_dir\': \'NNW\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.85, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 35, \'cloud\': 0, \'feelslike_c\': 29.4, \'feelslike_f\': 85.0, \'windchill_c\': 30.1, \'windchill_f\': 86.1, \'heatindex_c\': 29.5, \'heatindex_f\': 85.2, \'dewpoint_c\': 12.7, \'dewpoint_f\': 54.9, \'vis_km\': 4.5, \'vis_miles\': 2.0, \'uv\': 4.6, \'gust_mph\': 11.6, \'gust_kph\': 18.6}}", "score": 0.9876881, "raw_content": null}, {"url": "https://www.qweather.com/en/weather30d/kolkata-65929.html", "title": "Kolkata 30 days weather forecast, Kolkata weather forecast", "content": "Kolkata. West Bengal - India. 2025-11-08. In the next 30 days, there will be 3 days of rain, the Max Temp is 32°(14-Nov, 15-Nov, 16-Nov) and the Min Temp is", "score": 0.9014448, "raw_content": null}], "response_time": 1.51, "request_id": "fe456668-a1b3-4b09-8256-ddf08bd97d94"}', name='tavily_search', id='68ece54e-13f4-4f37-bfbf-f73c21b38188', tool_call_id='eb2f9dd7-3ef8-4ab8-93e7-9f017242d2cb')]]}}, 'name': 'ChatGoogleGenerativeAI', 'tags': ['seq:step:1'], 'run_id': 'd234db8a-39a2-4a03-9c0d-fed3a37d8317', 'metadata': {'langgraph_step': 3, 'langgraph_node': 'chat_node', 'langgraph_triggers': ('branch:to:chat_node',), 'langgraph_path': ('__pregel_pull', 'chat_node'), 'langgraph_checkpoint_ns': 'chat_node:e68bbd3f-b653-0b2d-1dcf-6d781041d8f9', 'checkpoint_ns': 'chat_node:e68bbd3f-b653-0b2d-1dcf-6d781041d8f9', 'ls_provider': 'google_genai', 'ls_model_name': 'gemini-2.5-flash', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['494a2b3c-d39d-4f81-9182-853b009c7c19', 'c20f58c8-a3f5-4d59-a3a3-d16a7eebc5bd']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content=[{'type': 'text', 'text': 'The current weather in Kolkata, India is Mist with a temperature of 30.0°C (feels like 29.4°C). The wind speed is 16.2 kph and the humidity is 35', 'extras': {'signature': '...'}}], additional_kwargs={}, response_metadata={'safety_ratings': [], 'grounding_metadata': {}, 'model_provider': 'google_genai'}, id='lc_run--d234db8a-39a2-4a03-9c0d-fed3a37d8317', usage_metadata={'input_tokens': 2380, 'output_tokens': 493, 'total_tokens': 2873, 'input_token_details': {'cache_read': 866}, 'output_token_details': {'reasoning': 444}})}, 'run_id': 'd234db8a-39a2-4a03-9c0d-fed3a37d8317', 'name': 'ChatGoogleGenerativeAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 3, 'langgraph_node': 'chat_node', 'langgraph_triggers': ('branch:to:chat_node',), 'langgraph_path': ('__pregel_pull', 'chat_node'), 'langgraph_checkpoint_ns': 'chat_node:e68bbd3f-b653-0b2d-1dcf-6d781041d8f9', 'checkpoint_ns': 'chat_node:e68bbd3f-b653-0b2d-1dcf-6d781041d8f9', 'ls_provider': 'google_genai', 'ls_model_name': 'gemini-2.5-flash', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['494a2b3c-d39d-4f81-9182-853b009c7c19', 'c20f58c8-a3f5-4d59-a3a3-d16a7eebc5bd']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='%.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'grounding_metadata': {}, 'model_provider': 'google_genai'}, id='lc_run--d234db8a-39a2-4a03-9c0d-fed3a37d8317', usage_metadata={'input_token_details': {'cache_read': 0}, 'total_tokens': 1, 'output_tokens': 1, 'input_tokens': 0, 'output_token_details': {'reasoning': 0}})}, 'run_id': 'd234db8a-39a2-4a03-9c0d-fed3a37d8317', 'name': 'ChatGoogleGenerativeAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 3, 'langgraph_node': 'chat_node', 'langgraph_triggers': ('branch:to:chat_node',), 'langgraph_path': ('__pregel_pull', 'chat_node'), 'langgraph_checkpoint_ns': 'chat_node:e68bbd3f-b653-0b2d-1dcf-6d781041d8f9', 'checkpoint_ns': 'chat_node:e68bbd3f-b653-0b2d-1dcf-6d781041d8f9', 'ls_provider': 'google_genai', 'ls_model_name': 'gemini-2.5-flash', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['494a2b3c-d39d-4f81-9182-853b009c7c19', 'c20f58c8-a3f5-4d59-a3a3-d16a7eebc5bd']}
# {'event': 'on_chat_model_stream', 'data': {'chunk': AIMessageChunk(content='', additional_kwargs={}, response_metadata={}, id='lc_run--d234db8a-39a2-4a03-9c0d-fed3a37d8317', chunk_position='last')}, 'run_id': 'd234db8a-39a2-4a03-9c0d-fed3a37d8317', 'name': 'ChatGoogleGenerativeAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 3, 'langgraph_node': 'chat_node', 'langgraph_triggers': ('branch:to:chat_node',), 'langgraph_path': ('__pregel_pull', 'chat_node'), 'langgraph_checkpoint_ns': 'chat_node:e68bbd3f-b653-0b2d-1dcf-6d781041d8f9', 'checkpoint_ns': 'chat_node:e68bbd3f-b653-0b2d-1dcf-6d781041d8f9', 'ls_provider': 'google_genai', 'ls_model_name': 'gemini-2.5-flash', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['494a2b3c-d39d-4f81-9182-853b009c7c19', 'c20f58c8-a3f5-4d59-a3a3-d16a7eebc5bd']}
# {'event': 'on_chat_model_end', 'data': {'output': AIMessage(content=[{'type': 'text', 'text': 'The current weather in Kolkata, India is Mist with a temperature of 30.0°C (feels like 29.4°C). The wind speed is 16.2 kph and the humidity is 35', 'extras': {'signature': '...'}}, '%.'], additional_kwargs={}, response_metadata={'safety_ratings': [], 'grounding_metadata': {}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'model_provider': 'google_genai'}, id='lc_run--d234db8a-39a2-4a03-9c0d-fed3a37d8317', usage_metadata={'input_tokens': 2380, 'output_tokens': 494, 'total_tokens': 2874, 'input_token_details': {'cache_read': 866}, 'output_token_details': {'reasoning': 444}}), 'input': {'messages': [[HumanMessage(content='what is the weather today in Kolkata, India', additional_kwargs={}, response_metadata={}, id='f7c10ce6-ffaa-4452-b816-1cd8aed2bc69'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'tavily_search', 'arguments': '{"query": "weather today in Kolkata, India"}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'grounding_metadata': {}, 'model_provider': 'google_genai'}, id='lc_run--e78d95e3-b434-45d6-95aa-b67d099f029b', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'weather today in Kolkata, India'}, 'id': 'eb2f9dd7-3ef8-4ab8-93e7-9f017242d2cb', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1546, 'output_tokens': 87, 'total_tokens': 1633, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 65}}), ToolMessage(content='{"query": "weather today in Kolkata, India", "follow_up_questions": null, "answer": null, "images": [], "results": [{"title": "Weather in Kolkata, India", "url": "https://www.weatherapi.com/", "content": "{\'location\': {\'name\': \'Kolkata\', \'region\': \'West Bengal\', \'country\': \'India\', \'lat\': 22.5697, \'lon\': 88.3697, \'tz_id\': \'Asia/Kolkata\', \'localtime_epoch\': 1762588137, \'localtime\': \'2025-11-08 13:18\'}, \'current\': {\'last_updated_epoch\': 1762587900, \'last_updated\': \'2025-11-08 13:15\', \'temp_c\': 30.0, \'temp_f\': 86.0, \'is_day\': 1, \'condition\': {\'text\': \'Mist\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/143.png\', \'code\': 1030}, \'wind_mph\': 10.1, \'wind_kph\': 16.2, \'wind_degree\': 341, \'wind_dir\': \'NNW\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.85, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 35, \'cloud\': 0, \'feelslike_c\': 29.4, \'feelslike_f\': 85.0, \'windchill_c\': 30.1, \'windchill_f\': 86.1, \'heatindex_c\': 29.5, \'heatindex_f\': 85.2, \'dewpoint_c\': 12.7, \'dewpoint_f\': 54.9, \'vis_km\': 4.5, \'vis_miles\': 2.0, \'uv\': 4.6, \'gust_mph\': 11.6, \'gust_kph\': 18.6}}", "score": 0.9876881, "raw_content": null}, {"url": "https://www.qweather.com/en/weather30d/kolkata-65929.html", "title": "Kolkata 30 days weather forecast, Kolkata weather forecast", "content": "Kolkata. West Bengal - India. 2025-11-08. In the next 30 days, there will be 3 days of rain, the Max Temp is 32°(14-Nov, 15-Nov, 16-Nov) and the Min Temp is", "score": 0.9014448, "raw_content": null}], "response_time": 1.51, "request_id": "fe456668-a1b3-4b09-8256-ddf08bd97d94"}', name='tavily_search', id='68ece54e-13f4-4f37-bfbf-f73c21b38188', tool_call_id='eb2f9dd7-3ef8-4ab8-93e7-9f017242d2cb')]]}}, 'run_id': 'd234db8a-39a2-4a03-9c0d-fed3a37d8317', 'name': 'ChatGoogleGenerativeAI', 'tags': ['seq:step:1'], 'metadata': {'langgraph_step': 3, 'langgraph_node': 'chat_node', 'langgraph_triggers': ('branch:to:chat_node',), 'langgraph_path': ('__pregel_pull', 'chat_node'), 'langgraph_checkpoint_ns': 'chat_node:e68bbd3f-b653-0b2d-1dcf-6d781041d8f9', 'checkpoint_ns': 'chat_node:e68bbd3f-b653-0b2d-1dcf-6d781041d8f9', 'ls_provider': 'google_genai', 'ls_model_name': 'gemini-2.5-flash', 'ls_model_type': 'chat', 'ls_temperature': 0.7}, 'parent_ids': ['494a2b3c-d39d-4f81-9182-853b009c7c19', 'c20f58c8-a3f5-4d59-a3a3-d16a7eebc5bd']}
# {'event': 'on_chain_start', 'data': {'input': {'messages': [HumanMessage(content='what is the weather today in Kolkata, India', additional_kwargs={}, response_metadata={}, id='f7c10ce6-ffaa-4452-b816-1cd8aed2bc69'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'tavily_search', 'arguments': '{"query": "weather today in Kolkata, India"}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'grounding_metadata': {}, 'model_provider': 'google_genai'}, id='lc_run--e78d95e3-b434-45d6-95aa-b67d099f029b', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'weather today in Kolkata, India'}, 'id': 'eb2f9dd7-3ef8-4ab8-93e7-9f017242d2cb', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1546, 'output_tokens': 87, 'total_tokens': 1633, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 65}}), ToolMessage(content='{"query": "weather today in Kolkata, India", "follow_up_questions": null, "answer": null, "images": [], "results": [{"title": "Weather in Kolkata, India", "url": "https://www.weatherapi.com/", "content": "{\'location\': {\'name\': \'Kolkata\', \'region\': \'West Bengal\', \'country\': \'India\', \'lat\': 22.5697, \'lon\': 88.3697, \'tz_id\': \'Asia/Kolkata\', \'localtime_epoch\': 1762588137, \'localtime\': \'2025-11-08 13:18\'}, \'current\': {\'last_updated_epoch\': 1762587900, \'last_updated\': \'2025-11-08 13:15\', \'temp_c\': 30.0, \'temp_f\': 86.0, \'is_day\': 1, \'condition\': {\'text\': \'Mist\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/143.png\', \'code\': 1030}, \'wind_mph\': 10.1, \'wind_kph\': 16.2, \'wind_degree\': 341, \'wind_dir\': \'NNW\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.85, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 35, \'cloud\': 0, \'feelslike_c\': 29.4, \'feelslike_f\': 85.0, \'windchill_c\': 30.1, \'windchill_f\': 86.1, \'heatindex_c\': 29.5, \'heatindex_f\': 85.2, \'dewpoint_c\': 12.7, \'dewpoint_f\': 54.9, \'vis_km\': 4.5, \'vis_miles\': 2.0, \'uv\': 4.6, \'gust_mph\': 11.6, \'gust_kph\': 18.6}}", "score": 0.9876881, "raw_content": null}, {"url": "https://www.qweather.com/en/weather30d/kolkata-65929.html", "title": "Kolkata 30 days weather forecast, Kolkata weather forecast", "content": "Kolkata. West Bengal - India. 2025-11-08. In the next 30 days, there will be 3 days of rain, the Max Temp is 32°(14-Nov, 15-Nov, 16-Nov) and the Min Temp is", "score": 0.9014448, "raw_content": null}], "response_time": 1.51, "request_id": "fe456668-a1b3-4b09-8256-ddf08bd97d94"}', name='tavily_search', id='68ece54e-13f4-4f37-bfbf-f73c21b38188', tool_call_id='eb2f9dd7-3ef8-4ab8-93e7-9f017242d2cb'), AIMessage(content=[{'type': 'text', 'text': 'The current weather in Kolkata, India is Mist with a temperature of 30.0°C (feels like 29.4°C). The wind speed is 16.2 kph and the humidity is 35', 'extras': {'signature': '...'}}, '%.'], additional_kwargs={}, response_metadata={'safety_ratings': [], 'grounding_metadata': {}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'model_provider': 'google_genai'}, id='lc_run--d234db8a-39a2-4a03-9c0d-fed3a37d8317', usage_metadata={'input_tokens': 2380, 'output_tokens': 494, 'total_tokens': 2874, 'input_token_details': {'cache_read': 866}, 'output_token_details': {'reasoning': 444}})]}}, 'name': 'tool_router', 'tags': ['seq:step:3'], 'run_id': '566cc05b-65e8-4e39-94b7-341dccb9f630', 'metadata': {'langgraph_step': 3, 'langgraph_node': 'chat_node', 'langgraph_triggers': ('branch:to:chat_node',), 'langgraph_path': ('__pregel_pull', 'chat_node'), 'langgraph_checkpoint_ns': 'chat_node:e68bbd3f-b653-0b2d-1dcf-6d781041d8f9'}, 'parent_ids': ['494a2b3c-d39d-4f81-9182-853b009c7c19', 'c20f58c8-a3f5-4d59-a3a3-d16a7eebc5bd']}
# {'event': 'on_chain_end', 'data': {'output': '__end__', 'input': {'messages': [HumanMessage(content='what is the weather today in Kolkata, India', additional_kwargs={}, response_metadata={}, id='f7c10ce6-ffaa-4452-b816-1cd8aed2bc69'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'tavily_search', 'arguments': '{"query": "weather today in Kolkata, India"}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'grounding_metadata': {}, 'model_provider': 'google_genai'}, id='lc_run--e78d95e3-b434-45d6-95aa-b67d099f029b', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'weather today in Kolkata, India'}, 'id': 'eb2f9dd7-3ef8-4ab8-93e7-9f017242d2cb', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1546, 'output_tokens': 87, 'total_tokens': 1633, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 65}}), ToolMessage(content='{"query": "weather today in Kolkata, India", "follow_up_questions": null, "answer": null, "images": [], "results": [{"title": "Weather in Kolkata, India", "url": "https://www.weatherapi.com/", "content": "{\'location\': {\'name\': \'Kolkata\', \'region\': \'West Bengal\', \'country\': \'India\', \'lat\': 22.5697, \'lon\': 88.3697, \'tz_id\': \'Asia/Kolkata\', \'localtime_epoch\': 1762588137, \'localtime\': \'2025-11-08 13:18\'}, \'current\': {\'last_updated_epoch\': 1762587900, \'last_updated\': \'2025-11-08 13:15\', \'temp_c\': 30.0, \'temp_f\': 86.0, \'is_day\': 1, \'condition\': {\'text\': \'Mist\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/143.png\', \'code\': 1030}, \'wind_mph\': 10.1, \'wind_kph\': 16.2, \'wind_degree\': 341, \'wind_dir\': \'NNW\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.85, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 35, \'cloud\': 0, \'feelslike_c\': 29.4, \'feelslike_f\': 85.0, \'windchill_c\': 30.1, \'windchill_f\': 86.1, \'heatindex_c\': 29.5, \'heatindex_f\': 85.2, \'dewpoint_c\': 12.7, \'dewpoint_f\': 54.9, \'vis_km\': 4.5, \'vis_miles\': 2.0, \'uv\': 4.6, \'gust_mph\': 11.6, \'gust_kph\': 18.6}}", "score": 0.9876881, "raw_content": null}, {"url": "https://www.qweather.com/en/weather30d/kolkata-65929.html", "title": "Kolkata 30 days weather forecast, Kolkata weather forecast", "content": "Kolkata. West Bengal - India. 2025-11-08. In the next 30 days, there will be 3 days of rain, the Max Temp is 32°(14-Nov, 15-Nov, 16-Nov) and the Min Temp is", "score": 0.9014448, "raw_content": null}], "response_time": 1.51, "request_id": "fe456668-a1b3-4b09-8256-ddf08bd97d94"}', name='tavily_search', id='68ece54e-13f4-4f37-bfbf-f73c21b38188', tool_call_id='eb2f9dd7-3ef8-4ab8-93e7-9f017242d2cb'), AIMessage(content=[{'type': 'text', 'text': 'The current weather in Kolkata, India is Mist with a temperature of 30.0°C (feels like 29.4°C). The wind speed is 16.2 kph and the humidity is 35', 'extras': {'signature': '...'}}, '%.'], additional_kwargs={}, response_metadata={'safety_ratings': [], 'grounding_metadata': {}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'model_provider': 'google_genai'}, id='lc_run--d234db8a-39a2-4a03-9c0d-fed3a37d8317', usage_metadata={'input_tokens': 2380, 'output_tokens': 494, 'total_tokens': 2874, 'input_token_details': {'cache_read': 866}, 'output_token_details': {'reasoning': 444}})]}}, 'run_id': '566cc05b-65e8-4e39-94b7-341dccb9f630', 'name': 'tool_router', 'tags': ['seq:step:3'], 'metadata': {'langgraph_step': 3, 'langgraph_node': 'chat_node', 'langgraph_triggers': ('branch:to:chat_node',), 'langgraph_path': ('__pregel_pull', 'chat_node'), 'langgraph_checkpoint_ns': 'chat_node:e68bbd3f-b653-0b2d-1dcf-6d781041d8f9'}, 'parent_ids': ['494a2b3c-d39d-4f81-9182-853b009c7c19', 'c20f58c8-a3f5-4d59-a3a3-d16a7eebc5bd']}
# {'event': 'on_chain_stream', 'run_id': 'c20f58c8-a3f5-4d59-a3a3-d16a7eebc5bd', 'name': 'chat_node', 'tags': ['graph:step:3'], 'metadata': {'langgraph_step': 3, 'langgraph_node': 'chat_node', 'langgraph_triggers': ('branch:to:chat_node',), 'langgraph_path': ('__pregel_pull', 'chat_node'), 'langgraph_checkpoint_ns': 'chat_node:e68bbd3f-b653-0b2d-1dcf-6d781041d8f9'}, 'data': {'chunk': {'messages': [AIMessage(content=[{'type': 'text', 'text': 'The current weather in Kolkata, India is Mist with a temperature of 30.0°C (feels like 29.4°C). The wind speed is 16.2 kph and the humidity is 35', 'extras': {'signature': '...'}}, '%.'], additional_kwargs={}, response_metadata={'safety_ratings': [], 'grounding_metadata': {}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'model_provider': 'google_genai'}, id='lc_run--d234db8a-39a2-4a03-9c0d-fed3a37d8317', usage_metadata={'input_tokens': 2380, 'output_tokens': 494, 'total_tokens': 2874, 'input_token_details': {'cache_read': 866}, 'output_token_details': {'reasoning': 444}})]}}, 'parent_ids': ['494a2b3c-d39d-4f81-9182-853b009c7c19']}
# {'event': 'on_chain_end', 'data': {'output': {'messages': [AIMessage(content=[{'type': 'text', 'text': 'The current weather in Kolkata, India is Mist with a temperature of 30.0°C (feels like 29.4°C). The wind speed is 16.2 kph and the humidity is 35', 'extras': {'signature': '...'}}, '%.'], additional_kwargs={}, response_metadata={'safety_ratings': [], 'grounding_metadata': {}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'model_provider': 'google_genai'}, id='lc_run--d234db8a-39a2-4a03-9c0d-fed3a37d8317', usage_metadata={'input_tokens': 2380, 'output_tokens': 494, 'total_tokens': 2874, 'input_token_details': {'cache_read': 866}, 'output_token_details': {'reasoning': 444}})]}, 'input': {'messages': [HumanMessage(content='what is the weather today in Kolkata, India', additional_kwargs={}, response_metadata={}, id='f7c10ce6-ffaa-4452-b816-1cd8aed2bc69'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'tavily_search', 'arguments': '{"query": "weather today in Kolkata, India"}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'grounding_metadata': {}, 'model_provider': 'google_genai'}, id='lc_run--e78d95e3-b434-45d6-95aa-b67d099f029b', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'weather today in Kolkata, India'}, 'id': 'eb2f9dd7-3ef8-4ab8-93e7-9f017242d2cb', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1546, 'output_tokens': 87, 'total_tokens': 1633, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 65}}), ToolMessage(content='{"query": "weather today in Kolkata, India", "follow_up_questions": null, "answer": null, "images": [], "results": [{"title": "Weather in Kolkata, India", "url": "https://www.weatherapi.com/", "content": "{\'location\': {\'name\': \'Kolkata\', \'region\': \'West Bengal\', \'country\': \'India\', \'lat\': 22.5697, \'lon\': 88.3697, \'tz_id\': \'Asia/Kolkata\', \'localtime_epoch\': 1762588137, \'localtime\': \'2025-11-08 13:18\'}, \'current\': {\'last_updated_epoch\': 1762587900, \'last_updated\': \'2025-11-08 13:15\', \'temp_c\': 30.0, \'temp_f\': 86.0, \'is_day\': 1, \'condition\': {\'text\': \'Mist\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/143.png\', \'code\': 1030}, \'wind_mph\': 10.1, \'wind_kph\': 16.2, \'wind_degree\': 341, \'wind_dir\': \'NNW\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.85, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 35, \'cloud\': 0, \'feelslike_c\': 29.4, \'feelslike_f\': 85.0, \'windchill_c\': 30.1, \'windchill_f\': 86.1, \'heatindex_c\': 29.5, \'heatindex_f\': 85.2, \'dewpoint_c\': 12.7, \'dewpoint_f\': 54.9, \'vis_km\': 4.5, \'vis_miles\': 2.0, \'uv\': 4.6, \'gust_mph\': 11.6, \'gust_kph\': 18.6}}", "score": 0.9876881, "raw_content": null}, {"url": "https://www.qweather.com/en/weather30d/kolkata-65929.html", "title": "Kolkata 30 days weather forecast, Kolkata weather forecast", "content": "Kolkata. West Bengal - India. 2025-11-08. In the next 30 days, there will be 3 days of rain, the Max Temp is 32°(14-Nov, 15-Nov, 16-Nov) and the Min Temp is", "score": 0.9014448, "raw_content": null}], "response_time": 1.51, "request_id": "fe456668-a1b3-4b09-8256-ddf08bd97d94"}', name='tavily_search', id='68ece54e-13f4-4f37-bfbf-f73c21b38188', tool_call_id='eb2f9dd7-3ef8-4ab8-93e7-9f017242d2cb')]}}, 'run_id': 'c20f58c8-a3f5-4d59-a3a3-d16a7eebc5bd', 'name': 'chat_node', 'tags': ['graph:step:3'], 'metadata': {'langgraph_step': 3, 'langgraph_node': 'chat_node', 'langgraph_triggers': ('branch:to:chat_node',), 'langgraph_path': ('__pregel_pull', 'chat_node'), 'langgraph_checkpoint_ns': 'chat_node:e68bbd3f-b653-0b2d-1dcf-6d781041d8f9'}, 'parent_ids': ['494a2b3c-d39d-4f81-9182-853b009c7c19']}
# {'event': 'on_chain_stream', 'run_id': '494a2b3c-d39d-4f81-9182-853b009c7c19', 'name': 'LangGraph', 'tags': [], 'metadata': {}, 'data': {'chunk': {'chat_node': {'messages': [AIMessage(content=[{'type': 'text', 'text': 'The current weather in Kolkata, India is Mist with a temperature of 30.0°C (feels like 29.4°C). The wind speed is 16.2 kph and the humidity is 35', 'extras': {'signature': '...'}}, '%.'], additional_kwargs={}, response_metadata={'safety_ratings': [], 'grounding_metadata': {}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'model_provider': 'google_genai'}, id='lc_run--d234db8a-39a2-4a03-9c0d-fed3a37d8317', usage_metadata={'input_tokens': 2380, 'output_tokens': 494, 'total_tokens': 2874, 'input_token_details': {'cache_read': 866}, 'output_token_details': {'reasoning': 444}})]}}}, 'parent_ids': []}
# {'event': 'on_chain_end', 'data': {'output': {'messages': [HumanMessage(content='what is the weather today in Kolkata, India', additional_kwargs={}, response_metadata={}, id='f7c10ce6-ffaa-4452-b816-1cd8aed2bc69'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'tavily_search', 'arguments': '{"query": "weather today in Kolkata, India"}'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'grounding_metadata': {}, 'model_provider': 'google_genai'}, id='lc_run--e78d95e3-b434-45d6-95aa-b67d099f029b', tool_calls=[{'name': 'tavily_search', 'args': {'query': 'weather today in Kolkata, India'}, 'id': 'eb2f9dd7-3ef8-4ab8-93e7-9f017242d2cb', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1546, 'output_tokens': 87, 'total_tokens': 1633, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 65}}), ToolMessage(content='{"query": "weather today in Kolkata, India", "follow_up_questions": null, "answer": null, "images": [], "results": [{"title": "Weather in Kolkata, India", "url": "https://www.weatherapi.com/", "content": "{\'location\': {\'name\': \'Kolkata\', \'region\': \'West Bengal\', \'country\': \'India\', \'lat\': 22.5697, \'lon\': 88.3697, \'tz_id\': \'Asia/Kolkata\', \'localtime_epoch\': 1762588137, \'localtime\': \'2025-11-08 13:18\'}, \'current\': {\'last_updated_epoch\': 1762587900, \'last_updated\': \'2025-11-08 13:15\', \'temp_c\': 30.0, \'temp_f\': 86.0, \'is_day\': 1, \'condition\': {\'text\': \'Mist\', \'icon\': \'//cdn.weatherapi.com/weather/64x64/day/143.png\', \'code\': 1030}, \'wind_mph\': 10.1, \'wind_kph\': 16.2, \'wind_degree\': 341, \'wind_dir\': \'NNW\', \'pressure_mb\': 1011.0, \'pressure_in\': 29.85, \'precip_mm\': 0.0, \'precip_in\': 0.0, \'humidity\': 35, \'cloud\': 0, \'feelslike_c\': 29.4, \'feelslike_f\': 85.0, \'windchill_c\': 30.1, \'windchill_f\': 86.1, \'heatindex_c\': 29.5, \'heatindex_f\': 85.2, \'dewpoint_c\': 12.7, \'dewpoint_f\': 54.9, \'vis_km\': 4.5, \'vis_miles\': 2.0, \'uv\': 4.6, \'gust_mph\': 11.6, \'gust_kph\': 18.6}}", "score": 0.9876881, "raw_content": null}, {"url": "https://www.qweather.com/en/weather30d/kolkata-65929.html", "title": "Kolkata 30 days weather forecast, Kolkata weather forecast", "content": "Kolkata. West Bengal - India. 2025-11-08. In the next 30 days, there will be 3 days of rain, the Max Temp is 32°(14-Nov, 15-Nov, 16-Nov) and the Min Temp is", "score": 0.9014448, "raw_content": null}], "response_time": 1.51, "request_id": "fe456668-a1b3-4b09-8256-ddf08bd97d94"}', name='tavily_search', id='68ece54e-13f4-4f37-bfbf-f73c21b38188', tool_call_id='eb2f9dd7-3ef8-4ab8-93e7-9f017242d2cb'), AIMessage(content=[{'type': 'text', 'text': 'The current weather in Kolkata, India is Mist with a temperature of 30.0°C (feels like 29.4°C). The wind speed is 16.2 kph and the humidity is 35', 'extras': {'signature': '...'}}, '%.'], additional_kwargs={}, response_metadata={'safety_ratings': [], 'grounding_metadata': {}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'model_provider': 'google_genai'}, id='lc_run--d234db8a-39a2-4a03-9c0d-fed3a37d8317', usage_metadata={'input_tokens': 2380, 'output_tokens': 494, 'total_tokens': 2874, 'input_token_details': {'cache_read': 866}, 'output_token_details': {'reasoning': 444}})]}}, 'run_id': '494a2b3c-d39d-4f81-9182-853b009c7c19', 'name': 'LangGraph', 'tags': [], 'metadata': {}, 'parent_ids': []}

# %% [markdown]
# How to refer to each token in nodes?
# - stream the outputs of on_chat_model_stream
# - data is event['data']['chunk'].content

# %%
initial_state = {"messages": [HumanMessage(content="what is the weather today in Kolkata, India")]}

events = app.astream_events(input=initial_state, version="v2")

async for event in events:
    if event.get("event") == "on_chat_model_stream":
        content = event['data']["chunk"].content
        print(content, end='', flush=True)
# Out:
# [{'type': 'text', 'text': 'The weather in Kolkata, India on November 8, 2025, is expected to be around 30.2°C with mist. The wind speed will be 16.6 kph from the NNW,', 'extras': {'signature': '...'}}] and the humidity will be 38%. The minimum temperature is likely to be 21°C and the maximum temperature might reach 30°C.
